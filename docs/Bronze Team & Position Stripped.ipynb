# %% [markdown]
# Bronze Team & Position Extraction

# %%
# %% Cell 0: Pipeline mode (full vs. incremental)
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("Pipeline_Mode").getOrCreate()

# Try to pull from spark.conf; defaults to "incremental" if not set
mode = spark.conf.get("pipeline.parameters.mode", "incremental").strip().lower()

# ───► Uncomment one of these lines to force “full” or “incremental” locally:
# mode = "full"
mode = "incremental"

print(f"▶️ Pipeline running in {mode!r} mode")
# Out:
# StatementMeta(, 912a7d70-7b9e-40db-834e-458fa50668d2, 14, Finished, Available, Finished)
# ▶️ Pipeline running in 'full' mode

# %%
# %% Cell 1: Build team_ids based on mode
import requests
from pyspark.sql.functions import col, max as spark_max

bronze = spark.table("SASPProd.bronze_teams")
max_id = bronze.select(spark_max(col("TeamID").cast("int"))).first()[0] or 0

if mode == "full":
    team_ids = list(range(1, max_id + 1))
else:
    start_id = max(1, max_id - 100)
    team_ids = list(range(start_id, max_id + 1))

# Detect truly new IDs above max_id
new_ids = []
curr = max_id + 1
while True:
    r = requests.get(f"https://virtual.sssfonline.com/api/shot/sasp-team/{curr}")
    if r.status_code == 404:
        break
    r.raise_for_status()
    new_ids.append(curr)
    curr += 1

team_ids += new_ids

print(f"▶️ Refreshing TeamIDs ({mode}): {team_ids[:3]} ... {team_ids[-3:]} (total {len(team_ids)})")
# Out:
# StatementMeta(, 912a7d70-7b9e-40db-834e-458fa50668d2, 15, Finished, Available, Finished)
# ▶️ Refreshing TeamIDs (full): [1, 2, 3] ... [3837, 3838, 3839] (total 3839)

# %%
# %% Cell Y: Fetch teams and build a Spark DataFrame (explicit schema)

import requests
import pandas as pd

from pyspark.sql import SparkSession
from pyspark.sql.functions import current_timestamp
from pyspark.sql.types import StructType, StructField, StringType

# ------------------------------------------------------------
# 1️⃣ Re‐use the existing SparkSession (created earlier in your notebook).
spark = SparkSession.builder.getOrCreate()
spark.sql("CREATE DATABASE IF NOT EXISTS SASPProd")
# ------------------------------------------------------------

# 2️⃣ Loop over `team_ids` (defined in Cell 1) and fetch each team.
rows = []
for tid in team_ids:
    url = f"https://virtual.sssfonline.com/api/shot/sasp-team/{tid}"
    try:
        r = requests.get(url)
        if r.status_code == 200:
            data = r.json()
            # Flatten exactly the fields your bronze_teams schema expects:
            flat = {
                "TeamID":         str(data.get("id", "")),
                "TeamName":       data.get("name", ""),
                "Location":       data.get("location", ""),
                "PrimaryContact": data.get("contact", ""),
                # …add any other nested keys here if your schema has more columns…
                "SourceURL":      url,                    # ← Track which URL succeeded
            }
            rows.append(flat)
        else:
            print(f"⚠️  Team {tid} returned status {r.status_code} (URL: {url})")
    except Exception as e:
        print(f"⚠️  Error fetching Team {tid} from {url}: {e}")

# 3️⃣ Define an explicit Spark schema that matches these columns:
schema = StructType([
    StructField("TeamID",         StringType(), nullable=True),
    StructField("TeamName",       StringType(), nullable=True),
    StructField("Location",       StringType(), nullable=True),
    StructField("PrimaryContact", StringType(), nullable=True),
    StructField("SourceURL",      StringType(), nullable=True),
])

# 4️⃣ Build a pandas DataFrame with exactly these column names (in this order).
#    Even if `rows == []`, pandas will create an empty DataFrame with the correct columns.
columns = ["TeamID", "TeamName", "Location", "PrimaryContact", "SourceURL"]
pdf = pd.DataFrame(rows, columns=columns)

# 5️⃣ Convert pandas → Spark using the explicit schema.
#    If `rows` was empty, this still works (Spark doesn’t try to infer from data).
if pdf.shape[0] == 0:
    # No rows: create an empty DataFrame with the schema
    spark_df = spark.createDataFrame([], schema=schema)
else:
    # At least 1 row: convert using the same schema
    spark_df = spark.createDataFrame(pdf, schema=schema)

# 6️⃣ Add an ingest timestamp column
spark_df = spark_df.withColumn("ingest_ts", current_timestamp())

# 7️⃣ Show exactly which TeamID + SourceURL rows are about to be upserted
print("🚀  The following teams (by SourceURL) will be upserted into bronze_teams:")
spark_df.select("TeamID", "SourceURL").show(truncate=False)

# 9️⃣ Sanity check: print schema & sample rows
spark_df.printSchema()
spark_df.show(10, truncate=False)
# Out:
# StatementMeta(, 912a7d70-7b9e-40db-834e-458fa50668d2, 16, Finished, Available, Finished)
# ⚠️  Team 1 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/1)
# ⚠️  Team 2 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/2)
# ⚠️  Team 3 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/3)
# ⚠️  Team 4 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/4)
# ⚠️  Team 5 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/5)
# ⚠️  Team 6 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/6)
# ⚠️  Team 7 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/7)
# ⚠️  Team 8 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/8)
# ⚠️  Team 9 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/9)
# ⚠️  Team 10 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/10)
# ⚠️  Team 11 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/11)
# ⚠️  Team 12 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/12)
# ⚠️  Team 13 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/13)
# ⚠️  Team 14 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/14)
# ⚠️  Team 15 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/15)
# ⚠️  Team 16 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/16)
# ⚠️  Team 17 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/17)
# ⚠️  Team 18 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/18)
# ⚠️  Team 19 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/19)
# ⚠️  Team 20 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/20)
# ⚠️  Team 21 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/21)
# ⚠️  Team 22 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/22)
# ⚠️  Team 23 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/23)
# ⚠️  Team 24 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/24)
# ⚠️  Team 25 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/25)
# ⚠️  Team 26 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/26)
# ⚠️  Team 27 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/27)
# ⚠️  Team 28 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/28)
# ⚠️  Team 29 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/29)
# ⚠️  Team 30 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/30)
# ⚠️  Team 31 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/31)
# ⚠️  Team 32 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/32)
# ⚠️  Team 33 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/33)
# ⚠️  Team 34 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/34)
# ⚠️  Team 35 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/35)
# ⚠️  Team 36 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/36)
# ⚠️  Team 37 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/37)
# ⚠️  Team 38 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/38)
# ⚠️  Team 39 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/39)
# ⚠️  Team 40 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/40)
# ⚠️  Team 41 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/41)
# ⚠️  Team 42 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/42)
# ⚠️  Team 43 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/43)
# ⚠️  Team 44 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/44)
# ⚠️  Team 45 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/45)
# ⚠️  Team 46 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/46)
# ⚠️  Team 47 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/47)
# ⚠️  Team 48 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/48)
# ⚠️  Team 49 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/49)
# ⚠️  Team 50 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/50)
# ⚠️  Team 51 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/51)
# ⚠️  Team 52 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team
returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/3815)
# ⚠️  Team 3816 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/3816)
# ⚠️  Team 3817 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/3817)
# ⚠️  Team 3818 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/3818)
# ⚠️  Team 3819 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/3819)
# ⚠️  Team 3820 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/3820)
# ⚠️  Team 3821 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/3821)
# ⚠️  Team 3822 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/3822)
# ⚠️  Team 3823 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/3823)
# ⚠️  Team 3824 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/3824)
# ⚠️  Team 3825 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/3825)
# ⚠️  Team 3826 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/3826)
# ⚠️  Team 3827 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/3827)
# ⚠️  Team 3828 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/3828)
# ⚠️  Team 3829 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/3829)
# ⚠️  Team 3830 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/3830)
# ⚠️  Team 3831 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/3831)
# ⚠️  Team 3832 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/3832)
# ⚠️  Team 3833 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/3833)
# ⚠️  Team 3834 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/3834)
# ⚠️  Team 3835 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/3835)
# ⚠️  Team 3836 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/3836)
# ⚠️  Team 3837 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/3837)
# ⚠️  Team 3838 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/3838)
# ⚠️  Team 3839 returned status 404 (URL: https://virtual.sssfonline.com/api/shot/sasp-team/3839)
# 🚀  The following teams (by SourceURL) will be upserted into bronze_teams:
# +------+---------+
# |TeamID|SourceURL|
# +------+---------+
# +------+---------+
#
# root
#  |-- TeamID: string (nullable = true)
#  |-- TeamName: string (nullable = true)
#  |-- Location: string (nullable = true)
#  |-- PrimaryContact: string (nullable = true)
#  |-- SourceURL: string (nullable = true)
#  |-- ingest_ts: timestamp (nullable = false)
#
# +------+--------+--------+--------------+---------+---------+
# |TeamID|TeamName|Location|PrimaryContact|SourceURL|ingest_ts|
# +------+--------+--------+--------------+---------+---------+
# +------+--------+--------+--------------+---------+---------+

# %%
# %% Cell Z: Upsert (merge) these back into bronze_teams

from delta.tables import DeltaTable
from pyspark.sql.functions import col

spark = SparkSession.builder.getOrCreate()

# 1️⃣ Check if spark_df is empty. If so, skip the merge.
#    This prevents errors when there are no new teams to insert/update.
row_count = spark_df.count()
if row_count == 0:
    print("ℹ️ spark_df is empty. No new teams to upsert.")
else:
    # 2️⃣ Narrow spark_df down to only the columns in bronze_teams.
    #    Here we assume the target schema for SASPProd.bronze_teams is:
    #      TeamID, TeamName, Location, PrimaryContact, ingest_ts
    #    (If your bronze_teams has additional columns, include them here as needed.)
    upsert_df = spark_df.select(
        col("TeamID"),
        col("TeamName"),
        col("Location"),
        col("PrimaryContact"),
        col("ingest_ts")
    )

    # 3️⃣ Load the existing bronze_teams Delta table
    bronze = DeltaTable.forName(spark, "SASPProd.bronze_teams")

    # 4️⃣ Perform the merge using only matching columns.
    #    WhenMatchedUpdateAll/WhenNotMatchedInsertAll will now only
    #    try to update/insert the five columns defined above.
    (
        bronze.alias("b")
              .merge(
                  upsert_df.alias("u"),
                  "b.TeamID = u.TeamID"      # key‐column for matching
              )
              .whenMatchedUpdateAll()
              .whenNotMatchedInsertAll()
              .execute()
    )

    print(f"✅ Upserted {row_count} teams into bronze_teams")
# Out:
# StatementMeta(, 912a7d70-7b9e-40db-834e-458fa50668d2, 17, Finished, Available, Finished)
# ℹ️ spark_df is empty. No new teams to upsert.
